# %%
import pandas as pd

# %%
fileJSON = '/home/colombelli/Desktop/har/1.json'
pd.read_json(file)
# Out:
#                                              results
# 0  {'jobId': 'cab65bcf-1c23-4418-b289-8e61db9918d...

# %%
import json

with open(fileJSON) as json_file:
    data = json.load(json_file)

# %%
a = data['results'][0]['result']['data']['dsr']['DS'][0]['ValueDicts']['D3']
len(a)
# Out:
# 4

# %%
b = data['results'][0]['result']['data']
with open('data.json', 'w') as f:
    json.dump(b, f)
b
# Out:
# {'descriptor': {'Select': [{'Kind': 1,
#     'Depth': 0,
#     'Value': 'G0',
#     'GroupKeys': [{'Source': {'Entity': 'dPostos', 'Property': 'NomeFantasia'},
#       'Calc': 'G0',
#       'IsSameAsSelect': True}],
#     'Name': 'dPostos.NomeFantasia'},
#    {'Kind': 1,
#     'Depth': 1,
#     'Value': 'G1',
#     'GroupKeys': [{'Source': {'Entity': 'dPostos', 'Property': 'Endereco'},
#       'Calc': 'G1',
#       'IsSameAsSelect': True}],
#     'Name': 'dPostos.Endereco'},
#    {'Kind': 1,
#     'Depth': 4,
#     'Value': 'G4',
#     'GroupKeys': [{'Source': {'Entity': 'dItens', 'Property': 'Item_Display'},
#       'Calc': 'G4',
#       'IsSameAsSelect': True}],
#     'Name': 'dItens.Item_Display'},
#    {'Kind': 2,
#     'Value': 'M0',
#     'Format': '0',
#     'Name': 'dRespostas.Status Atual'},
#    {'Kind': 1,
#     'Depth': 2,
#     'Value': 'G2',
#     'GroupKeys': [{'Source': {'Entity': 'dPostos', 'Property': 'Fone'},
#       'Calc': 'G2',
#       'IsSameAsSelect': True}],
# ...

# %%
for k in data['results'][0]['result']['data']['dsr']['DS'][0]:
    print(k)
# Out:
# N
# PH
# IC
# RT
# ValueDicts

# %%
pd.DataFrame.from_dict(data['results'][0]['result']['data']['dsr']['DS'][0]['PH'][0])
# Out:
#                                                    DM0
# 0    {'S': [{'N': 'G0', 'T': 1}], 'G0': '247 GUARAP...
# 1    {'G0': '30GM COMBUSTIVEIS', 'M': [{'DM1': [{'G...
# 2    {'G0': 'A E K COMERCIO DE COMBUSTIVEIS LTDA', ...
# 3    {'G0': 'A P JD ANCHIETA  ARRASTAO DA ESTRADA',...
# 4    {'G0': 'A T GARCIA COMBUSTIVEIS', 'M': [{'DM1'...
# ..                                                 ...
# 117  {'G0': 'AUTO POSTO DE SUMARE', 'M': [{'DM1': [...
# 118  {'G0': 'AUTO POSTO DO ARLEI', 'M': [{'DM1': [{...
# 119  {'G0': 'AUTO POSTO DO BOSQUE', 'M': [{'DM1': [...
# 120  {'G0': 'AUTO POSTO DO TRABALHO VALQUEIRE', 'M'...
# 121  {'G0': 'AUTO POSTO DOIS IRMAOS', 'M': [{'DM1':...
#
# [122 rows x 1 columns]
