# %%
import pandas as pd

kaggle = pd.read_csv('/home/colombelli/Desktop/dados/2019-1_CA.csv', encoding='utf-16', engine='python', sep='\t')

# %%
kaggle.Produto.unique()
# Out:
# array(['DIESEL', 'DIESEL S10', 'ETANOL', 'GASOLINA', 'GNV'], dtype=object)

# %%
df = kaggle[kaggle.Produto == 'DIESEL']
df2 = kaggle[kaggle.Produto == 'DIESEL S10']

# %%
df2
# Out:
#        Região - Sigla Estado - Sigla    Município  \
# 2                  CO             DF     BRASILIA
# 3                  CO             DF     BRASILIA
# 10                 CO             DF     BRASILIA
# 11                 CO             DF     BRASILIA
# 16                 CO             DF     BRASILIA
# ...               ...            ...          ...
# 496169             SE             SP  VOTUPORANGA
# 496170             SE             SP  VOTUPORANGA
# 496171             SE             SP  VOTUPORANGA
# 496172             SE             SP  VOTUPORANGA
# 496173             SE             SP  VOTUPORANGA
#
#                                                   Revenda  CNPJ da Revenda  \
# 2                         ABRITTA POSTOS DE SERVIÇOS LTDA   10668863000195
# 3                         ABRITTA POSTOS DE SERVIÇOS LTDA   10668863000195
# 10                    AGUAS CLARAS POSTO DE SERVICOS LTDA    6006437000119
# ...

# %%
df_conc = pd.concat([df,df2], axis=0)
df_conc
# Out:
#        Região - Sigla Estado - Sigla    Município  \
# 0                  CO             DF     BRASILIA
# 1                  CO             DF     BRASILIA
# 8                  CO             DF     BRASILIA
# 9                  CO             DF     BRASILIA
# 66                 CO             DF     BRASILIA
# ...               ...            ...          ...
# 496169             SE             SP  VOTUPORANGA
# 496170             SE             SP  VOTUPORANGA
# 496171             SE             SP  VOTUPORANGA
# 496172             SE             SP  VOTUPORANGA
# 496173             SE             SP  VOTUPORANGA
#
#                                                   Revenda  CNPJ da Revenda  \
# 0                         ABRITTA POSTOS DE SERVIÇOS LTDA   10668863000195
# 1                         ABRITTA POSTOS DE SERVIÇOS LTDA   10668863000195
# 8                     AGUAS CLARAS POSTO DE SERVICOS LTDA    6006437000119
# ...

# %%
del df_conc['Região - Sigla'] 

df_conc
# Out:
#        Estado - Sigla    Município  \
# 0                  DF     BRASILIA
# 1                  DF     BRASILIA
# 8                  DF     BRASILIA
# 9                  DF     BRASILIA
# 66                 DF     BRASILIA
# ...               ...          ...
# 496169             SP  VOTUPORANGA
# 496170             SP  VOTUPORANGA
# 496171             SP  VOTUPORANGA
# 496172             SP  VOTUPORANGA
# 496173             SP  VOTUPORANGA
#
#                                                   Revenda  CNPJ da Revenda  \
# 0                         ABRITTA POSTOS DE SERVIÇOS LTDA   10668863000195
# 1                         ABRITTA POSTOS DE SERVIÇOS LTDA   10668863000195
# 8                     AGUAS CLARAS POSTO DE SERVICOS LTDA    6006437000119
# 9                     AGUAS CLARAS POSTO DE SERVICOS LTDA    6006437000119
# 66                           AUTO POSTO AGUAS CLARAS LTDA   38076089000142
# ...                                                   ...              ...
# ...

# %%
firebaseConfig = {
    "apiKey": "AIzaSyAXdChyhwAAy_QsoKRnEvu-eWDdQOCwMTk",
    "authDomain": "pontocerto-2bdfd.firebaseapp.com",
    "databaseURL": "https://pontocerto-2bdfd.firebaseio.com",
    "projectId": "pontocerto-2bdfd",
    "storageBucket": "pontocerto-2bdfd.appspot.com",
    "messagingSenderId": "853009810633",
    "appId": "1:853009810633:web:14faa75bcc6a04009b3918",
    "serviceAccount":"/home/colombelli/Desktop/dados/pontocerto-2bdfd-firebase-adminsdk-3u9ay-bc98ffbe79.json",
  };

# %%
import pyrebase

# %%
firebase = pyrebase.initialize_app(firebaseConfig)

# %%
firebase

# %%
j = df_conc[0:10].to_json()

# %%
db = firebase.database()

# %%
db.child("test").push(j)
# Out:
# {'name': '-M9iJaRqNc-9RQBO97SS'}

# %%
del df_conc['Bandeira'] 

df_conc
# Out:
#        Estado - Sigla    Município  \
# 0                  DF     BRASILIA
# 1                  DF     BRASILIA
# 8                  DF     BRASILIA
# 9                  DF     BRASILIA
# 66                 DF     BRASILIA
# ...               ...          ...
# 496169             SP  VOTUPORANGA
# 496170             SP  VOTUPORANGA
# 496171             SP  VOTUPORANGA
# 496172             SP  VOTUPORANGA
# 496173             SP  VOTUPORANGA
#
#                                                   Revenda Valor de Venda
# 0                         ABRITTA POSTOS DE SERVIÇOS LTDA          3,799
# 1                         ABRITTA POSTOS DE SERVIÇOS LTDA          3,799
# 8                     AGUAS CLARAS POSTO DE SERVICOS LTDA          3,799
# 9                     AGUAS CLARAS POSTO DE SERVICOS LTDA          3,799
# 66                           AUTO POSTO AGUAS CLARAS LTDA           3,59
# ...                                                   ...            ...
# ...

# %%
from copy import deepcopy

# %%
fsttry = deepcopy(df_conc)

# %%
test = fsttry.iloc[:, 0:3]
test
# Out:
#        Estado - Sigla    Município  \
# 0                  DF     BRASILIA
# 1                  DF     BRASILIA
# 8                  DF     BRASILIA
# 9                  DF     BRASILIA
# 66                 DF     BRASILIA
# ...               ...          ...
# 496169             SP  VOTUPORANGA
# 496170             SP  VOTUPORANGA
# 496171             SP  VOTUPORANGA
# 496172             SP  VOTUPORANGA
# 496173             SP  VOTUPORANGA
#
#                                                   Revenda
# 0                         ABRITTA POSTOS DE SERVIÇOS LTDA
# 1                         ABRITTA POSTOS DE SERVIÇOS LTDA
# 8                     AGUAS CLARAS POSTO DE SERVICOS LTDA
# 9                     AGUAS CLARAS POSTO DE SERVICOS LTDA
# 66                           AUTO POSTO AGUAS CLARAS LTDA
# ...                                                   ...
# 496169  VITORIA COMERCIO DE COMBUSTIVEIS DE VOTUPORANG...
# 496170  VITORIA COMERCIO DE COMBUSTIVEIS DE VOTUPORANG...
# ...

# %%
uniques = test.drop_duplicates(subset=None, keep='first')

# %%
final = df_conc.loc[list(uniques.index), :]

# %%
final.to_csv('/home/colombelli/Desktop/dados/processed.csv', index=False)

# %%
for i, row in final.iterrows():
    print(row['Município'], '\n')
# Out:
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# BRASILIA
#
# AGUAS LINDAS DE GOIAS
#
# AGUAS LINDAS DE GOIAS
#
# AGUAS LINDAS DE GOIAS
#
# AGUAS LINDAS DE GOIAS
#
# AGUAS LINDAS DE GOIAS
#
# AGUAS LINDAS DE GOIAS
#
# AGUAS LINDAS DE GOIAS
# ...

# %%
final
# Out:
#        Estado - Sigla    Município  \
# 0                  DF     BRASILIA
# 8                  DF     BRASILIA
# 66                 DF     BRASILIA
# 86                 DF     BRASILIA
# 102                DF     BRASILIA
# ...               ...          ...
# 494436             SP   VOTORANTIM
# 494904             SP   VOTORANTIM
# 495034             SP   VOTORANTIM
# 496032             SP  VOTUPORANGA
# 496044             SP  VOTUPORANGA
#
#                                                 Revenda Valor de Venda
# 0                       ABRITTA POSTOS DE SERVIÇOS LTDA          3,799
# 8                   AGUAS CLARAS POSTO DE SERVICOS LTDA          3,799
# 66                         AUTO POSTO AGUAS CLARAS LTDA           3,59
# 86                            AUTO POSTO ALMENARA LTDA.          3,759
# 102                             AUTO POSTO BR 060 LTDA.          3,499
# ...                                                 ...            ...
# ...
